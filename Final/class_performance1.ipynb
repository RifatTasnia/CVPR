# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# %%
model = keras.Sequential(
    [
        layers.Conv2D(32,(3,3), activation="relu", input_shape=(28,28,1)),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Conv2D(64,(3,3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="sgd",
    metrics=["accuracy"],
)

# %%
history_sgd = model.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 22s 12ms/step - loss: 0.5651 - accuracy: 0.8330 - val_loss: 0.1539 - val_accuracy: 0.9580
# Epoch 2/10
# 1688/1688 [==============================] - 20s 12ms/step - loss: 0.1494 - accuracy: 0.9541 - val_loss: 0.1009 - val_accuracy: 0.9715
# Epoch 3/10
# 1688/1688 [==============================] - 21s 13ms/step - loss: 0.1031 - accuracy: 0.9682 - val_loss: 0.0771 - val_accuracy: 0.9785
# Epoch 4/10
# 1688/1688 [==============================] - 21s 13ms/step - loss: 0.0820 - accuracy: 0.9742 - val_loss: 0.0726 - val_accuracy: 0.9787
# Epoch 5/10
# 1688/1688 [==============================] - 23s 14ms/step - loss: 0.0692 - accuracy: 0.9785 - val_loss: 0.0651 - val_accuracy: 0.9818
# Epoch 6/10
# 1688/1688 [==============================] - 23s 14ms/step - loss: 0.0608 - accuracy: 0.9806 - val_loss: 0.0736 - val_accuracy: 0.9780
# Epoch 7/10
# 1688/1688 [==============================] - 24s 14ms/step - loss: 0.0541 - accuracy: 0.9836 - val_loss: 0.0536 - val_accuracy: 0.9838
# Epoch 8/10
# 1688/1688 [==============================] - 24s 15ms/step - loss: 0.0487 - accuracy: 0.9847 - val_loss: 0.0643 - val_accuracy: 0.9822
# Epoch 9/10
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.0440 - accuracy: 0.9861 - val_loss: 0.0534 - val_accuracy: 0.9848
# Epoch 10/10
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.0406 - accuracy: 0.9873 - val_loss: 0.0490 - val_accuracy: 0.9868

# %%
model_adam = keras.Sequential(
    [
        layers.Conv2D(32,(3,3), activation="relu", input_shape=(28,28,1)),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Conv2D(64,(3,3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model_adam.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
history_adam = model_adam.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 29s 17ms/step - loss: 0.1355 - accuracy: 0.9587 - val_loss: 0.0490 - val_accuracy: 0.9850
# Epoch 2/10
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.0444 - accuracy: 0.9861 - val_loss: 0.0362 - val_accuracy: 0.9892
# Epoch 3/10
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.0302 - accuracy: 0.9902 - val_loss: 0.0325 - val_accuracy: 0.9905
# Epoch 4/10
# 1688/1688 [==============================] - 26s 16ms/step - loss: 0.0215 - accuracy: 0.9930 - val_loss: 0.0367 - val_accuracy: 0.9912
# Epoch 5/10
# 1688/1688 [==============================] - 26s 16ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0406 - val_accuracy: 0.9903
# Epoch 6/10
# 1688/1688 [==============================] - 27s 16ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.0417 - val_accuracy: 0.9902
# Epoch 7/10
# 1688/1688 [==============================] - 24s 14ms/step - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0371 - val_accuracy: 0.9923
# Epoch 8/10
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0489 - val_accuracy: 0.9907
# Epoch 9/10
# 1688/1688 [==============================] - 27s 16ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0438 - val_accuracy: 0.9912
# Epoch 10/10
# 1688/1688 [==============================] - 31s 18ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.0529 - val_accuracy: 0.9908

# %%
model_rmsprop = keras.Sequential(
    [
        layers.Conv2D(32,(3,3), activation="relu", input_shape=(28,28,1)),
        layers.MaxPooling2D(pool_size=(2,2)),
        layers.Conv2D(64,(3,3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model_rmsprop.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="rmsprop",
    metrics=["accuracy"],
)

# %%
history_rmsprop = model_rmsprop.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 25s 14ms/step - loss: 0.1314 - accuracy: 0.9589 - val_loss: 0.0539 - val_accuracy: 0.9852
# Epoch 2/10
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.0447 - accuracy: 0.9868 - val_loss: 0.0375 - val_accuracy: 0.9898
# Epoch 3/10
# 1688/1688 [==============================] - 27s 16ms/step - loss: 0.0319 - accuracy: 0.9904 - val_loss: 0.0346 - val_accuracy: 0.9908
# Epoch 4/10
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.0242 - accuracy: 0.9925 - val_loss: 0.0300 - val_accuracy: 0.9915
# Epoch 5/10
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.0200 - accuracy: 0.9940 - val_loss: 0.0527 - val_accuracy: 0.9887
# Epoch 6/10
# 1688/1688 [==============================] - 27s 16ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 0.0392 - val_accuracy: 0.9918
# Epoch 7/10
# 1688/1688 [==============================] - 25s 15ms/step - loss: 0.0153 - accuracy: 0.9957 - val_loss: 0.0468 - val_accuracy: 0.9912
# Epoch 8/10
# 1688/1688 [==============================] - 26s 16ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.0426 - val_accuracy: 0.9908
# Epoch 9/10
# 1688/1688 [==============================] - 27s 16ms/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 0.0595 - val_accuracy: 0.9888
# Epoch 10/10
# 1688/1688 [==============================] - 26s 15ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.0517 - val_accuracy: 0.9910

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(history_sgd.history["accuracy"])
plt.plot(history_adam.history["accuracy"])
plt.plot(history_rmsprop.history["accuracy"])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["SGD", "ADAM", "RMSProp"], loc="lower right")
plt.show()

plt.figure(figsize=(15,5))
plt.subplot(1,2,2)
plt.plot(history_sgd.history["val_accuracy"])
plt.plot(history_adam.history["val_accuracy"])
plt.plot(history_rmsprop.history["val_accuracy"])
plt.title("Model Validation Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["SGD", "ADAM", "RMSProp"], loc="lower right")
plt.show()
